# %%
import sys
sys.path.append('emavfi')
from emavfi.utils import InputPadder
from emavfi.Trainer import Model
import emavfi.config as cfg
import cv2
import os
import torch
import numpy as np
import argparse
from glob import glob
from natsort import natsorted

# %%
# TTA = True
# I0_ = (torch.tensor(I0.transpose(2, 0, 1)).cuda() / 255.).unsqueeze(0)
# I2_ = (torch.tensor(I2.transpose(2, 0, 1)).cuda() / 255.).unsqueeze(0)

# padder = InputPadder(I0_.shape, divisor=32)
# I0_, I2_ = padder.pad(I0_, I2_)

cfg.MODEL_CONFIG['LOGNAME'] = 'ours_t'
cfg.MODEL_CONFIG['MODEL_ARCH'] = cfg.init_model_config(
    F=32,
    depth=[2, 2, 2, 4, 4]
)
model = Model(-1)
model.load_model()
model.eval()
model.device()
print(model.net)
# Out:
# MultiScaleFlow(
#   (feature_bone): MotionFormer(
#     (block1): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=16)
#         (2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PReLU(num_parameters=16)
#       )
#     )
#     (patch_embed2): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=32)
#     )
#     (block2): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=32)
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PReLU(num_parameters=32)
#       )
#     )
#     (patch_embed3): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=64)
#     )
#     (block3): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=64)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PReLU(num_parameters=64)
#       )
#     )
#     (norm4): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#     (patch_embed4): CrossScalePatchEmbed(
#       (layers): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(32, 16, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1))
#         (2): Conv2d(32, 16, kernel_size=(3, 3), stride=(4, 4), padding=(2, 2), dilation=(2, 2))
#         (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(8, 8), padding=(1, 1))
#         (4): Conv2d(16, 16, kernel_size=(3, 3), stride=(8, 8), padding=(2, 2), dilation=(2, 2))
#         (5): Conv2d(16, 16, kernel_size=(3, 3), stride=(8, 8), padding=(3, 3), dilation=(3, 3))
#         (6): Conv2d(16, 16, kernel_size=(3, 3), stride=(8, 8), padding=(4, 4), dilation=(4, 4))
#       )
#       (proj): Conv2d(112, 128, kernel_size=(1, 1), stride=(1, 1))
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (block4): ModuleList(
#       (0): MotionFormerBlock(
#         (norm1): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#         (attn): InterFrameAttention(
#           (q): Linear(in_features=128, out_features=128, bias=True)
#           (kv): Linear(in_features=128, out_features=256, bias=True)
#           (cor_embed): Linear(in_features=2, out_features=64, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (motion_proj): Linear(in_features=64, out_features=64, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (dwconv): DWConv(
#             (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           )
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (1): MotionFormerBlock(
#         (norm1): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#         (attn): InterFrameAttention(
#           (q): Linear(in_features=128, out_features=128, bias=True)
#           (kv): Linear(in_features=128, out_features=256, bias=True)
#           (cor_embed): Linear(in_features=2, out_features=64, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (motion_proj): Linear(in_features=64, out_features=64, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (dwconv): DWConv(
#             (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           )
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (norm5): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#     (patch_embed5): OverlapPatchEmbed(
#       (proj): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (block5): ModuleList(
#       (0): MotionFormerBlock(
#         (norm1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (attn): InterFrameAttention(
#           (q): Linear(in_features=256, out_features=256, bias=True)
#           (kv): Linear(in_features=256, out_features=512, bias=True)
#           (cor_embed): Linear(in_features=2, out_features=128, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=256, out_features=256, bias=True)
#           (motion_proj): Linear(in_features=128, out_features=128, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=256, out_features=1024, bias=True)
#           (dwconv): DWConv(
#             (dwconv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#           )
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1024, out_features=256, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (1): MotionFormerBlock(
#         (norm1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (attn): InterFrameAttention(
#           (q): Linear(in_features=256, out_features=256, bias=True)
#           (kv): Linear(in_features=256, out_features=512, bias=True)
#           (cor_embed): Linear(in_features=2, out_features=128, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=256, out_features=256, bias=True)
#           (motion_proj): Linear(in_features=128, out_features=128, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=256, out_features=1024, bias=True)
#           (dwconv): DWConv(
#             (dwconv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#           )
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1024, out_features=256, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (block): ModuleList(
#     (0): Head(
#       (upsample): Sequential(
#         (0): PixelShuffle(upscale_factor=2)
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (conv): Sequential(
#         (0): Sequential(
#           (0): Conv2d(70, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=64)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=64)
#         )
#         (2): Sequential(
#           (0): Conv2d(64, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=5)
#         )
#       )
#     )
#     (1): Head(
#       (upsample): Sequential(
#         (0): PixelShuffle(upscale_factor=2)
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (conv): Sequential(
#         (0): Sequential(
#           (0): Conv2d(49, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=64)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=64)
#         )
#         (2): Sequential(
#           (0): Conv2d(64, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=5)
#         )
#       )
#     )
#   )
#   (unet): Unet(
#     (down0): Conv2(
#       (conv1): Sequential(
#         (0): Conv2d(49, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): PReLU(num_parameters=64)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=64)
#       )
#     )
#     (down1): Conv2(
#       (conv1): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): PReLU(num_parameters=128)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=128)
#       )
#     )
#     (down2): Conv2(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): PReLU(num_parameters=256)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=256)
#       )
#     )
#     (down3): Conv2(
#       (conv1): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): PReLU(num_parameters=512)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=512)
#       )
#     )
#     (up0): Sequential(
#       (0): ConvTranspose2d(1024, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=256)
#     )
#     (up1): Sequential(
#       (0): ConvTranspose2d(512, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=128)
#     )
#     (up2): Sequential(
#       (0): ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=64)
#     )
#     (up3): Sequential(
#       (0): ConvTranspose2d(128, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=32)
#     )
#     (conv): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
print(model.net)
# Out:
# MultiScaleFlow(
#   (feature_bone): MotionFormer(
#     (block1): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=16)
#         (2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PReLU(num_parameters=16)
#       )
#     )
#     (patch_embed2): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=32)
#     )
#     (block2): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=32)
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PReLU(num_parameters=32)
#       )
#     )
#     (patch_embed3): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=64)
#     )
#     (block3): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=64)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PReLU(num_parameters=64)
#       )
#     )
#     (norm4): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#     (patch_embed4): CrossScalePatchEmbed(
#       (layers): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(32, 16, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1))
#         (2): Conv2d(32, 16, kernel_size=(3, 3), stride=(4, 4), padding=(2, 2), dilation=(2, 2))
#         (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(8, 8), padding=(1, 1))
#         (4): Conv2d(16, 16, kernel_size=(3, 3), stride=(8, 8), padding=(2, 2), dilation=(2, 2))
#         (5): Conv2d(16, 16, kernel_size=(3, 3), stride=(8, 8), padding=(3, 3), dilation=(3, 3))
#         (6): Conv2d(16, 16, kernel_size=(3, 3), stride=(8, 8), padding=(4, 4), dilation=(4, 4))
#       )
#       (proj): Conv2d(112, 128, kernel_size=(1, 1), stride=(1, 1))
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (block4): ModuleList(
#       (0): MotionFormerBlock(
#         (norm1): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#         (attn): InterFrameAttention(
#           (q): Linear(in_features=128, out_features=128, bias=True)
#           (kv): Linear(in_features=128, out_features=256, bias=True)
#           (cor_embed): Linear(in_features=2, out_features=64, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (motion_proj): Linear(in_features=64, out_features=64, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (dwconv): DWConv(
#             (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           )
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (1): MotionFormerBlock(
#         (norm1): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#         (attn): InterFrameAttention(
#           (q): Linear(in_features=128, out_features=128, bias=True)
#           (kv): Linear(in_features=128, out_features=256, bias=True)
#           (cor_embed): Linear(in_features=2, out_features=64, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (motion_proj): Linear(in_features=64, out_features=64, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (dwconv): DWConv(
#             (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           )
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (norm5): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#     (patch_embed5): OverlapPatchEmbed(
#       (proj): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (block5): ModuleList(
#       (0): MotionFormerBlock(
#         (norm1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (attn): InterFrameAttention(
#           (q): Linear(in_features=256, out_features=256, bias=True)
#           (kv): Linear(in_features=256, out_features=512, bias=True)
#           (cor_embed): Linear(in_features=2, out_features=128, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=256, out_features=256, bias=True)
#           (motion_proj): Linear(in_features=128, out_features=128, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=256, out_features=1024, bias=True)
#           (dwconv): DWConv(
#             (dwconv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#           )
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1024, out_features=256, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (1): MotionFormerBlock(
#         (norm1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (attn): InterFrameAttention(
#           (q): Linear(in_features=256, out_features=256, bias=True)
#           (kv): Linear(in_features=256, out_features=512, bias=True)
#           (cor_embed): Linear(in_features=2, out_features=128, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=256, out_features=256, bias=True)
#           (motion_proj): Linear(in_features=128, out_features=128, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=256, out_features=1024, bias=True)
#           (dwconv): DWConv(
#             (dwconv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#           )
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1024, out_features=256, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (block): ModuleList(
#     (0): Head(
#       (upsample): Sequential(
#         (0): PixelShuffle(upscale_factor=2)
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (conv): Sequential(
#         (0): Sequential(
#           (0): Conv2d(70, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=64)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=64)
#         )
#         (2): Sequential(
#           (0): Conv2d(64, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=5)
#         )
#       )
#     )
#     (1): Head(
#       (upsample): Sequential(
#         (0): PixelShuffle(upscale_factor=2)
#         (1): PixelShuffle(upscale_factor=2)
#       )
#       (conv): Sequential(
#         (0): Sequential(
#           (0): Conv2d(49, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=64)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=64)
#         )
#         (2): Sequential(
#           (0): Conv2d(64, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): PReLU(num_parameters=5)
#         )
#       )
#     )
#   )
#   (unet): Unet(
#     (down0): Conv2(
#       (conv1): Sequential(
#         (0): Conv2d(49, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): PReLU(num_parameters=64)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=64)
#       )
#     )
#     (down1): Conv2(
#       (conv1): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): PReLU(num_parameters=128)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=128)
#       )
#     )
#     (down2): Conv2(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): PReLU(num_parameters=256)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=256)
#       )
#     )
#     (down3): Conv2(
#       (conv1): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): PReLU(num_parameters=512)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PReLU(num_parameters=512)
#       )
#     )
#     (up0): Sequential(
#       (0): ConvTranspose2d(1024, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=256)
#     )
#     (up1): Sequential(
#       (0): ConvTranspose2d(512, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=128)
#     )
#     (up2): Sequential(
#       (0): ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=64)
#     )
#     (up3): Sequential(
#       (0): ConvTranspose2d(128, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): PReLU(num_parameters=32)
#     )
#     (conv): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
import gdown

gdown.download_folder("https://drive.google.com/drive/folders/1pzl4R0nGajgJJQOIBuSAaIxlfNz70OeJ?usp=sharing")
# Out:
# Retrieving folder list
# Processing file 1djQRRbUAYqiK9-Osw4JjLMRHSScOOQx3 cosine_100epochs.pkl
# Processing file 1J7llNxRFRkxd5ikrOb6JEU3tvuuTXIcL fixed_lr.pkl
# Processing file 1565-dZkoFEkYSaeukLq1ZUTOStABgBRi ours_small_ours_small_t_epoch_99.pkl
# Building directory structure completed
# Retrieving folder list completed
# Building directory structure
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1djQRRbUAYqiK9-Osw4JjLMRHSScOOQx3
# From (redirected): https://drive.google.com/uc?id=1djQRRbUAYqiK9-Osw4JjLMRHSScOOQx3&confirm=t&uuid=5474a88d-c43f-4948-9b32-38ae6aad6884
# To: /home/arpitsah/Desktop/vlr_project/frame-interpolation-VLR/EMA_VFI weights/cosine_100epochs.pkl
# 100%|██████████| 58.7M/58.7M [00:03<00:00, 18.1MB/s]
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1J7llNxRFRkxd5ikrOb6JEU3tvuuTXIcL
# From (redirected): https://drive.google.com/uc?id=1J7llNxRFRkxd5ikrOb6JEU3tvuuTXIcL&confirm=t&uuid=dc99982e-d3e6-47d2-a77e-cdc37bc98229
# To: /home/arpitsah/Desktop/vlr_project/frame-interpolation-VLR/EMA_VFI weights/fixed_lr.pkl
# 100%|██████████| 58.4M/58.4M [00:02<00:00, 20.1MB/s]
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1565-dZkoFEkYSaeukLq1ZUTOStABgBRi
# From (redirected): https://drive.google.com/uc?id=1565-dZkoFEkYSaeukLq1ZUTOStABgBRi&confirm=t&uuid=b46e1c8c-9860-4a3b-8799-e2903ddd05b6
# To: /home/arpitsah/Desktop/vlr_project/frame-interpolation-VLR/EMA_VFI weights/ours_small_ours_small_t_epoch_99.pkl
# 100%|██████████| 58.7M/58.7M [00:03<00:00, 16.1MB/s]
# Download completed
# ['/home/arpitsah/Desktop/vlr_project/frame-interpolation-VLR/EMA_VFI weights/cosine_100epochs.pkl',
#  '/home/arpitsah/Desktop/vlr_project/frame-interpolation-VLR/EMA_VFI weights/fixed_lr.pkl',
#  '/home/arpitsah/Desktop/vlr_project/frame-interpolation-VLR/EMA_VFI weights/ours_small_ours_small_t_epoch_99.pkl']
